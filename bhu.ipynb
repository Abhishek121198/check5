# %%
import numpy as np
import pandas as pd
import skfuzzy as fuz
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_6684/71777665.py in <module>
#       1 import numpy as np
#       2 import pandas as pd
# ----> 3 import skfuzzy as fuz
#
# ModuleNotFoundError: No module named 'skfuzzy'

# %%
pip install -U scikit-fuzzy
# Out:
# ...
#   Created wheel for scikit-fuzzy: filename=scikit_fuzzy-0.4.2-py3-none-any.whl size=894089 sha256=cd451b1cf7ae07dda6cdb641a829832c567a7ec5f67dd51071cd88204adb4739
#   Stored in directory: c:\users\user\appdata\local\pip\cache\wheels\32\2c\a1\a90a7d7dd8448ec029f298a61f3490275e99b17aa348be675c
# Successfully built scikit-fuzzy
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np
import skfuzzy as fz

# %%
import matplotlib. pyplot as plt
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %%
x = np.linspace(start = 0, stop = 75, num = 75, endpoint = True, retstep =
False)
al = [0, 25, 50]
bl = [25, 50,75]

# %%
union = fz.fuzzy_or(x, young,x,middle)[1]
intersection = fz.fuzzy_and(x, young,x,middle)[1]
complement = fz.fuzzy_not(young)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_6684/3732568477.py in <module>
# ----> 1 union = fz.fuzzy_or(x, young,x,middle)[1]
#       2 intersection = fz.fuzzy_and(x, young,x,middle)[1]
#       3 complement = fz.fuzzy_not(young)
#
# NameError: name 'young' is not defined

# %%
young = fz.membership.trimf(x, al)
middle = fz.membership.trimf(x, bl)
one = np.ones(75)
zeros = np.zeros((75, ))

# %%
union = fz.fuzzy_or(x, young,x,middle)[1]

# %%
intersection = fz.fuzzy_and(x, young,x,middle)[1]
complement = fz.fuzzy_not(young)

# %%
plt.figure()
plt.plot(x, union)

# %%
plt.figure()
plt.plot(x, intersection)

# %%
plt.figure()
plt.plot(x, complement)

# %%
x = np.linspace(start = 0, stop = 75, num = 75, endpoint = True, retstep =False)
b1 = 0.5
c1 = 0.7
b2 = 0.5
c2 = 0.3
a = 10
b = 50
c = 40
d = 1.3

# %%
 diff = fz.membership.dsigmf(x, b1,c1,b2,c2)

# %%
plt.figure()
plt.plot(x, diff)

# %%
bell = fz.membership.gbellmf(x, a,b,c)

# %%
plt.figure()
plt.plot(x, bell)

# %%
tri=fz.membership.trapmf(x, abcd)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_6684/2824375501.py in <module>
# ----> 1 tri=fz.membership.trapmf(x, abcd)
#
# NameError: name 'abcd' is not defined

# %%
plt.figure()
plt.plot(x, young)

# %%
plt.figure()
plt.plot(x, middle)

# %%
x2 = np.linspace(start = 0, stop = 75, num = 75, endpoint = True, retstep =
False)
a2 = [0, 25, 50,75]
b2 = [25, 50,75,100]

# %%
trapz = fz.membership.trapmf(x2, a2)

# %%
plt.figure()
plt.plot(x2, trapz)

# %%
gauss=fz.membership.gaussmf(x, 40, 10)

# %%
plt.figure()
plt.plot(x2, gauss)
